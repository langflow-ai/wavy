# %% [markdown]
# ### Imports

# %%
import sys
sys.path.append('../')

from wavy import *
import pandas as pd

# %% [markdown]
# ### Load data

# %%
data_pd = pd.read_pickle('processed.pkl')
data_pd = data_pd.iloc[0:8,:]
data_pd
# Out:
#                   LNC                                                    MAS  \
#                  Open       High        Low      Close     Volume       Open
# Date
# 2005-12-21  38.127885  39.324626  38.120589  39.207870  2190100.0  18.991695
# 2005-12-22  39.185984  39.324630  38.879500  39.040039  1095500.0  19.085703
# 2005-12-23  39.061931  39.397604  38.959771  39.324631   588800.0  18.954090
# 2005-12-27  39.514374  39.514374  38.981676  39.237080   932700.0  18.929008
# 2005-12-28  39.455973  39.696782  39.244353  39.310028   427200.0  18.853798
# 2005-12-29  39.302738  39.463277  38.923283  38.937878   532300.0  18.803659
# 2005-12-30  38.799235  38.799235  38.412484  38.697075   594100.0  18.791119
# 2006-01-03  38.872209  39.098424  38.303028  39.061935   743300.0  19.167201
#
#                                                         ...       CSX  \
#                  High        Low      Close     Volume  ...      Open
# ...

# %%
datablock = from_dataframe(data_pd)
datablock
# Out:
#                   LNC                                                    MAS  \
#                  Open       High        Low      Close     Volume       Open
# Date
# 2005-12-21  38.127885  39.324626  38.120589  39.207870  2190100.0  18.991695
# 2005-12-22  39.185984  39.324630  38.879500  39.040039  1095500.0  19.085703
# 2005-12-23  39.061931  39.397604  38.959771  39.324631   588800.0  18.954090
# 2005-12-27  39.514374  39.514374  38.981676  39.237080   932700.0  18.929008
# 2005-12-28  39.455973  39.696782  39.244353  39.310028   427200.0  18.853798
# 2005-12-29  39.302738  39.463277  38.923283  38.937878   532300.0  18.803659
# 2005-12-30  38.799235  38.799235  38.412484  38.697075   594100.0  18.791119
# 2006-01-03  38.872209  39.098424  38.303028  39.061935   743300.0  19.167201
#
#                                                         ...       CSX  \
#                  High        Low      Close     Volume  ...      Open
# ...

# %%
type(datablock)
# Out:
# wavy.block.Block

# %%
datablock = datablock.filter(assets=['MSFT', 'AAPL'], channels=['Open', 'Close'])

# %%
x = datablock.iloc[3:5,:]

# %%
y = datablock.iloc[5:7,:]

# %%
x
# Out:
#                  MSFT                 AAPL
#                  Open      Close      Open     Close
# Date
# 2005-12-27  19.438692  19.278402  2.261349  2.268378
# 2005-12-28  19.314840  19.227409  2.275712  2.248209

# %%
y
# Out:
#                  MSFT                 AAPL
#                  Open      Close      Open     Close
# Date
# 2005-12-29  19.241974  19.139973  2.254626  2.183424
# 2005-12-30  19.052540  19.052540  2.166923  2.196870

# %%
timepairs = [TimePair(x, y), TimePair(x, y)]

# %%
type(timepairs)
# Out:
# list

# %%
panel = from_pairs(timepairs)

# %%
panel
# Out:
# size                               2
# lookback                           2
# horizon                            2
# gap                                0
# num_xassets                        2
# num_yassets                        2
# num_xchannels                      2
# num_ychannels                      2
# start            2005-12-27 00:00:00
# end              2005-12-30 00:00:00
# Name: Panel, dtype: object
# <Panel, size 2>

# %%
panel[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# pairs
panel.pairs

# %%
panel.lookback

# %%
panel.x.index

# %%
panel.y.index

# %%
list(panel.x.index) + list(panel.y.index)

# %%
sorted(list(set(list(panel.x.index) + list(panel.y.index))))

# %%
panel.shape

# %% [markdown]
# # Function `countna`

# %%
x = datablock.iloc[3:5,:]
y = datablock.iloc[5:7,:]
z = datablock.iloc[4:6,:]
w = datablock.iloc[6:8,:]

x.matrix[0][2] = np.nan
x.matrix[1][1] = np.nan
y.matrix[0][1] = np.nan
y.matrix[1][3] = np.nan

timepairs = [TimePair(x, y), TimePair(z, w)]
panel_nan = from_pairs(timepairs)

# %%
a = panel_nan.countna()

# %%
a = panel_nan.dropna()

# %%
a

# %%
a.x.last

# %%
x_nan = panel_nan.x.findna()
y_nan = panel_nan.y.findna()
nan_values = list(set(x_nan + y_nan))

# %%
nan_values

# %%
type(nan_values)

# %%
a = panel_nan[0]

# %%
a

# %% [markdown]
# ## Function `from_xy_data`

# %%
# data_pd.iloc[0:8,:]
data_pd = pd.read_pickle('processed.pkl')
x = data_pd.iloc[0:20,:]
y = data_pd.iloc[20:40,:]

# %%
type(x)

# %%
y.shape

# %%
from_xy_data(x, y, 5, 5, 0)
