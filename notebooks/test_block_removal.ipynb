# %%
from datetime import datetime
import numpy as np
import pandas as pd
import tensorflow as tf

import sys
sys.path.append('../')

# from wavy import panel
# from wavy import side
# from wavy import model
import wavy

# %%
df = pd.read_pickle('../data/processed.pkl')

# %%
df.head(5)
# Out:
#                   LNC                                                    MAS  \
#                  Open       High        Low      Close     Volume       Open
# Date
# 2005-12-21  38.127885  39.324626  38.120589  39.207870  2190100.0  18.991695
# 2005-12-22  39.185984  39.324630  38.879500  39.040039  1095500.0  19.085703
# 2005-12-23  39.061931  39.397604  38.959771  39.324631   588800.0  18.954090
# 2005-12-27  39.514374  39.514374  38.981676  39.237080   932700.0  18.929008
# 2005-12-28  39.455973  39.696782  39.244353  39.310028   427200.0  18.853798
#
#                                                         ...       CSX  \
#                  High        Low      Close     Volume  ...      Open
# Date                                                    ...
# 2005-12-21  19.154659  18.903944  19.085712  1384200.0  ...  6.245725
# 2005-12-22  19.298810  18.910202  18.929007  1576900.0  ...  6.381336
# 2005-12-23  18.954090  18.684571  18.816196  2090500.0  ...  6.297691
# 2005-12-27  18.991687  18.803650  18.847525  1609000.0  ...  6.520750
# 2005-12-28  18.935281  18.747245  18.803656  2026300.0  ...  6.419358
#
#                                                             CI             \
#                 High       Low     Close     Volume       Open       High
# Date
# 2005-12-21  6.399080  6.245725  6.362326  8358000.0  36.945102  37.462575
# 2005-12-22  6.420626  6.361058  6.410487  5344800.0  37.409841  37.630677
# 2005-12-23  6.520752  6.297691  6.468790  3630000.0  37.376876  37.432909
# 2005-12-27  6.527087  6.369931  6.400348  4905000.0  37.195584  37.455973
# 2005-12-28  6.459914  6.363592  6.419358  3578400.0  37.241735  37.449383
#
#
#                   Low      Close     Volume
# Date
# 2005-12-21  36.895658  37.370289  2805900.0
# 2005-12-22  37.073647  37.327442  2296800.0
# 2005-12-23  36.905546  37.261517  1686000.0
# 2005-12-27  36.961570  37.116482  1917900.0
# 2005-12-28  37.109892  37.251621  1248900.0
#
# [5 rows x 2085 columns]

# %%
df = df.loc[:, (['AAPL', 'MSFT'], ['Open', 'Close'])]

# %%
df
# Out:
#                   AAPL                    MSFT
#                   Open       Close        Open       Close
# Date
# 2005-12-21    2.218566    2.246069   19.577126   19.475122
# 2005-12-22    2.258598    2.261960   19.460543   19.373114
# 2005-12-23    2.266543    2.241485   19.322122   19.409552
# 2005-12-27    2.261349    2.268378   19.438692   19.278402
# 2005-12-28    2.275712    2.248209   19.314840   19.227409
# ...                ...         ...         ...         ...
# 2020-11-04  113.943419  114.752022  214.020004  216.389999
# 2020-11-05  117.746855  118.824997  222.039993  223.289993
# 2020-11-06  118.320000  118.690002  222.259995  223.720001
# 2020-11-09  120.500000  116.320000  224.440002  218.389999
# 2020-11-10  115.550003  115.970001  214.500000  211.009995
#
# [3747 rows x 4 columns]

# %%
panel = wavy.create_panel(df, lookback = 5, horizon = 1, gap = 0)

# %%
panel
# Out:
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# <Panel, size 3742>

# %%
panel.x[0]
# Out:
#                 AAPL                 MSFT
#                 Open     Close       Open      Close
# Date
# 2005-12-21  2.218566  2.246069  19.577126  19.475122
# 2005-12-22  2.258598  2.261960  19.460543  19.373114
# 2005-12-23  2.266543  2.241485  19.322122  19.409552
# 2005-12-27  2.261349  2.268378  19.438692  19.278402
# 2005-12-28  2.275712  2.248209  19.314840  19.227409

# %%
panel.x[1]
# Out:
#                 AAPL                 MSFT
#                 Open     Close       Open      Close
# Date
# 2005-12-22  2.258598  2.261960  19.460543  19.373114
# 2005-12-23  2.266543  2.241485  19.322122  19.409552
# 2005-12-27  2.261349  2.268378  19.438692  19.278402
# 2005-12-28  2.275712  2.248209  19.314840  19.227409
# 2005-12-29  2.254626  2.183424  19.241974  19.139973

# %%
a = panel.x.shift()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1h/2q97f2rx4qz77b9l1gp7wvvm0000gn/T/ipykernel_47262/690128468.py in <module>
# ----> 1 a = panel.x.shift()
#
# ~/GitHub/wavy/notebooks/../wavy/side.py in shift(self, window)
#     655             new_values = self.blocks[new_index] if new_index is not None else np.ones(self.blocks[0].shape) * np.nan
#     656             # new_block = from_matrix(values=new_values, index=block.index, assets=block.assets, channels=block.channels)
# --> 657             new_block = pd.DataFrame(data=new_values, index=block.index, columns=block.columns)
#     658             new_side.append(new_block)
#     659
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     629
#     630         if isinstance(data, (BlockManager, ArrayManager)):
# --> 631             mgr = self._init_mgr(
#     632                 data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     633             )
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/generic.py in _init_mgr(cls, mgr, axes, dtype, copy)
#     266         for a, axe in axes.items():
#     267             if axe is not None:
# --> 268                 axe = ensure_index(axe)
#     269                 bm_axis = cls._get_block_manager_axis(a)
#     270                 mgr = mgr.reindex_axis(axe, axis=bm_axis)
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    7041             return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7042     else:
# -> 7043         return Index._with_infer(index_like, copy=copy)
#    7044
#    7045
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/indexes/base.py in _with_infer(cls, *args, **kwargs)
#     678         with warnings.catch_warnings():
#     679             warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 680             result = cls(*args, **kwargs)
#     681
#     682         if result.dtype == _dtype_obj and not result._is_multi:
#
# ~/GitHub/wavy/.env/lib/python3.8/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     506
#     507         elif is_scalar(data):
# --> 508             raise cls._scalar_data_error(data)
#     509         elif hasattr(data, "__array__"):
#     510             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#
# TypeError: Index(...) must be called with a collection of some kind, 0 was passed

# %%
a[0]

# %%
a[1]

# %%
new_side = []
window=1

for i, block in enumerate(panel.x.blocks):
    new_index = i - window
    new_index = new_index if new_index >= 0 and new_index < len(panel.x.blocks) else None
    new_values = panel.x.blocks[new_index].values if new_index is not None else np.ones(panel.x.blocks[0].shape) * np.nan
    # new_block = from_matrix(values=new_values, index=block.index, assets=block.assets, channels=block.channels)
    new_block = pd.DataFrame(data=new_values, index=block.index, columns=block.columns)
    new_side.append(new_block)
# Out:
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# ...
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                       3742
# lookback                      5
# horizon                       1
# gap                           0
# start       2005-12-21 00:00:00
# end         2020-11-10 00:00:00
# xlevels                       2
# ylevels                       2
# Name: Panel, dtype: object
# size                      3742
# start      2005-12-21 00:00:00
# end        2020-11-09 00:00:00
# xlevels                      2
# ylevels                      2
# Name: Side, dtype: object

# %%
b = wavy.Side(new_side)

# %%
b[0]
# Out:
#            AAPL       MSFT
#            Open Close Open Close
# Date
# 2005-12-21  NaN   NaN  NaN   NaN
# 2005-12-22  NaN   NaN  NaN   NaN
# 2005-12-23  NaN   NaN  NaN   NaN
# 2005-12-27  NaN   NaN  NaN   NaN
# 2005-12-28  NaN   NaN  NaN   NaN

# %%
b[1]
# Out:
#                 AAPL                 MSFT
#                 Open     Close       Open      Close
# Date
# 2005-12-22  2.218566  2.246069  19.577126  19.475122
# 2005-12-23  2.258598  2.261960  19.460543  19.373114
# 2005-12-27  2.266543  2.241485  19.322122  19.409552
# 2005-12-28  2.261349  2.268378  19.438692  19.278402
# 2005-12-29  2.275712  2.248209  19.314840  19.227409

# %%
type(panel)

# %%
type(panel.x)

# %%
type(panel.x[0])

# %%
panel.columns

# %%
len(panel1.columns.keys())

# %%
panel1.x[1].values.shape

# %%
first =

# %%
a = panel1.x.drop(columns='Open', axis=1, level=1)

# %%
a[0]

# %%
panel_.y[0]

# %%
panel_.y = panel_.y.wmean()

# %%
panel_.y = panel_.y.wpct_change()

# %%
panel_.y[1]

# %%
panel_.y = panel_.y > 0

# %%
panel_.y[2]

# %%
panel_.y  = panel_.y > panel_.y[('AAPL', 'Open')]

# %%
model_ = model.Baseline(panel_)

# %%
block.wcount(axis=1)

# %%
block.wkurt(axis=0)

# %%
block.wkurt(axis=1)

# %%
block.wkurtosis(axis=0)

# %%
block.wkurtosis(axis=1)

# %%
block.wmad(axis=0)

# %%
block.wmad(axis=1)

# %%
block.wmax(axis=0)

# %%
block.wmax(axis=1)

# %%
block.wmin(axis=0)

# %%
block.wmean()

# %%
block.wmedian()

# %%
block.wnunique(axis=0)

# %%
block.wprod()

# %%
block.wquantile()

# %%
block.wsem()

# %%
block.wskew(axis=1)

# %%
block.wstd()

# %%
block.wsum()

# %%
block.wvar()

# %%
callable(df.fillna)

# %%
hasattr(block.Block, 'start')

# %%
hasattr(block.Block, 'start') and callable(getattr(block.Block, 'start'))

# %%
callable(getattr(block.Block, 'start'))

# %%
hasattr(pd.DataFrame, 'T')

# %%
hasattr(block.Block, 'T')

# %%
hasattr(pd.DataFrame, 'T') and not hasattr(block.Block, 'T')

# %%
dir(block.Block)

# %%
a = panel_.x[0]

# %%
super()

# %%
a.__class__.__dict__

# %%
a.magicmethod('T')

# %%
a.add(1)

# %%
a.mean()

# %%
a.min()

# %%
a.max()

# %%
a.mad()

# %%
dir(pd.DataFrame)

# %%
type(df.memory_usage())

# %%
type(a.mean())

# %%
for c in block.super():
    print(c)

# %%
panel_.plot_block(12)

# %%
panel_.plot_slider(20)

# %%
panel_.x.plot_slider(20)

# %%
panel_.x.plot_block(20)

# %%
panel_.x[12].plot()

# %%
new = panel_.x.side_sample(frac=0.01)

# %%
new[0]

# %%
len(new)

# %%
new_panel = panel_.panel_sample(100)

# %%
len(new_panel)

# %%
panel_.x[0].min()

# %%
panel_.x[0].mean().to_frame()

# %%
type(panel_.x[0].mean().to_frame())

# %%
a = pd.DataFrame([1,2,3,4,5])

# %%
type(a.mean())

# %%
# Implement to_frame().T in Block functions that return series (Gabriel)
# Resample 
# Event tag for plots

# %%
block_ = panel_.x[0]

# %%
block_.mean()

# %%
panel_.x[0].mean()

# %%
panel_.x.min()

# %%
type(panel_.x[0].mean().to_frame().T)

# %%
panel_.x

# %%
panel_.x.first

# %%
panel_.plot_slider(100)

# %%
panel_.plot_block(20)

# %%
panel_.x.plot_slider()

# %% [markdown]
# # Test functions example

# %%
side = panel_.x

# %%
side[0]

# %%
side = side.side_shift(window = 1)

# %%
side[0]

# %%
side[0].is_valid

# %%
side[1]

# %%
side = side.side_diff(window = 1)

# %%
side[1]

# %%
side = side.side_pct_change(window = 1)

# %%
side[1]

# %% [markdown]
# # Graph types
#
# Separate X from Y

# %%
panel_.plot_slider()

# %%
panel_.plot_block(3)

# %%
panel_.x.plot_block(20)

# %%
panel_.x.plot_slider()

# %%
panel.x[0].index

# %%
panel_.x[20].plot()

# %%
panel.x[0]

# %%
panel_.x[2].plot()

# %%
panel.y[0]

# %%
panel.set_training_split()

# %%
panel.x.first

# %%
panel.shape

# %% [markdown]
# # Baseline

# %%
baseline = model.Baseline(panel_, metrics=['SE', 'MSE', 'RMSE'])

# %%
baseline.panel

# %%
predicted = baseline.predict()

# %%
panel_.test.y[0]

# %%
predicted

# %%
a = baseline.panel.test.y

# %%
a.plot_slider()

# %%
b = a.wshift(1)

# %%
predicted_val = baseline.predict_val()

# %%
predicted_val[0]

# %%
panel_.gap

# %%
panel.val.y[0]

# %%
predicted_val[2]

# %%
baseline.evaluate('test')

# %%
# m = tf.keras.metrics.MeanSquaredError()
# m.update_state(panel.test.y.tensor3d, predicted.tensor3d)
# m.result().numpy()

# %% [markdown]
# # DenseModel

# %%
densemodel = model.DenseModel(panel, model_type="regression")

# %%
densemodel.fit()

# %%
densemodel.model.summary()

# %%
predicted = densemodel.predict()

# %%
predicted[0]

# %%
panel.test.y[0]

# %%
densemodel.evaluate('test')

# %%
import numpy as np
import pandas as pd
import plotly as px
import plotly.graph_objects as go
import plotly.express as px

pd.set_option("multi_sparse", True)  # To see multilevel indexes
pd.options.plotting.backend = "plotly"

from plotly.subplots import make_subplots

def pair_plot(panel, idx):

    cmap = px.colors.qualitative.Plotly

    fig = make_subplots(rows=len(panel.channels), cols=len(panel.assets), subplot_titles=panel.assets, shared_xaxes=True)

    for j, channel in enumerate(panel.channels):
        c = cmap[j]
        for i, asset in enumerate(panel.assets):

            showlegend = i <= 0
            x_df = panel.x[idx].filter(assets=asset, channels=channel)
            y_df = panel.y[idx].filter(assets=asset, channels=channel)
            # y_df = panel.y[idx].filter(assets=asset, channels=channel)

            x_trace = go.Scatter(x=x_df.index, y=x_df.values.flatten(),
                            line=dict(width=2, color=c), showlegend=showlegend, name=channel)

            y_trace = go.Scatter(x=y_df.index, y=y_df.values.flatten(),
                                line=dict(width=2, dash='dot', color=c), showlegend=False)

            fig.add_trace(x_trace, row=j+1, col=i+1)
            fig.add_trace(y_trace, row=j+1, col=i+1)

    fig.update_layout(showlegend=True)
    fig.show()

# %%
panel.x.as_dataframe()

# %%
# panel = panel.filter('AAPL', ['High', 'Low'])
pair_plot(panel, 0)

# %%
panel = panel.filter('LNC', ['Open', 'High'])
panel[0].plot()
panel.y_ = model.predict()

# %% [markdown]
# # ConvModel

# %%
convmodel = model.ConvModel(panel, model_type="regression")

# %%
convmodel.fit()

# %%
convmodel.model.summary()

# %%
predicted = convmodel.predict()

# %%
predicted[0]

# %%
panel.test.y[0]

# %%
convmodel.evaluate()

# %% [markdown]
# # LinearRegression

# %%
linearRegression = model.LinearRegression(panel)

# %%
linearRegression.fit()

# %%
predicted = linearRegression.predict()

# %%
predicted[0]

# %%
panel.test.y[0]

# %%
linearRegression.evaluate()

# %% [markdown]
# # Teste SeparateAssetModel

# %%
panel.val.x[0]

# %%
test_splits = panel.val.x._split_assets()

# %%
x_train = [x.tensor3d for x in test_splits]

# %%
# pd.DataFrame(x_train)

# %%
test_splits[0].tensor3d[0]

# %%
test_splits[0].tensor4d[0]

# %%
pd.DataFrame(panel.val.x.tensor4d)

# %% [markdown]
# # SeparateAssetModel

# %%
separateAssetModel = model.SeparateAssetModel(panel, loss='MSE', optimizer='adam', metrics=['MAE'], hidden_activation='relu', last_activation='linear')

# %%
separateAssetModel.fit()

# %%
separateAssetModel.model.summary()

# %%
predicted = separateAssetModel.predict()

# %%
predicted[0]

# %%
panel.test.y[0]

# %%
separateAssetModel.evaluate()

# %% [markdown]
# # SeparateAssetConvModel

# %%
separateAssetConvModel = model.SeparateAssetConvModel(panel, loss='MSE', optimizer='adam', metrics=['MAE'], hidden_activation='relu', last_activation='linear')

# %%
separateAssetConvModel.fit()

# %%
separateAssetConvModel.model.summary()

# %%
predicted = separateAssetConvModel.predict()

# %%
predicted[0]

# %%
panel.test.y[0]

# %%
separateAssetConvModel.evaluate()

# %% [markdown]
# # Test Docstrings

# %%
densemodel = model.DenseModel()
