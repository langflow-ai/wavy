# %%
import sys
sys.path.append('../')

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import yfinance as yf

import wavy

# %%
# tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0].Symbol

# %%
msft = yf.Ticker("MSFT")
# get historical market data from 2005 on
hist = msft.history(period="max", start="2005-01-01")

# %%
df = hist[['High']]
df = df.pct_change().dropna()

# %%
df.head()
# Out:
#                     High
# Date
# 2005-01-04  5.565865e-03
# 2005-01-05 -2.390470e-07
# 2005-01-06 -1.476133e-03
# 2005-01-07 -6.282367e-03
# 2005-01-10 -1.115438e-03

# %%
x, y = wavy.create_panels(df, lookback=10, horizon=1)

# %%
x[0]
# Out:
#                     High
# Date
# 2005-01-04  5.565865e-03
# 2005-01-05 -2.390470e-07
# 2005-01-06 -1.476133e-03
# 2005-01-07 -6.282367e-03
# 2005-01-10 -1.115438e-03
# 2005-01-11 -1.489171e-03
# 2005-01-12  1.118466e-03
# 2005-01-13 -1.862601e-03
# 2005-01-14 -1.305981e-02
# 2005-01-18 -3.780011e-03

# %%
x_resample = x.resample(10, 'spaced')
y_resample = y.match(x_resample)
# Out:
#   0%|          | 0/4343 [00:00<?, ?it/s]

# %%
from wavy.plot import PanelFigure
import plotly.io as pio

pio.templates.default = "plotly_white"

fig = PanelFigure()
fig.split_sets(y)
fig.add_line(y)

# fig.add_threshline(y, 0.1, -0.1)
# fig.add_dotline(y.test)

fig.show()

# %%
# self.fig = self.fig.update_layout(showlegend=False)

# %%
from wavy.plot import plot_frame, plot_slider

fig = plot_frame(x, 1)
fig.show()

# %%
fig = plot_slider(x)
fig.show()

# %%
fig = PanelFigure()
fig.plot_frame(x, 2)

# %%
from wavy.plot import PanelFigure

fig = PanelFigure()
fig.add_dotline(y)

# %%
fig.show()

# %%
model = wavy.LinearRegression(x, y)
model.fit()
y_pred = model.predict()
# Out:
#   0%|          | 0/3128 [00:00<?, ?it/s]
#   0%|          | 0/781 [00:00<?, ?it/s]
#   0%|          | 0/434 [00:00<?, ?it/s]
#   0%|          | 0/3128 [00:00<?, ?it/s]
#   0%|          | 0/781 [00:00<?, ?it/s]
#   0%|          | 0/434 [00:00<?, ?it/s]
# 2022-04-19 23:17:09.780950: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 98/98 [==============================] - 0s 2ms/step - loss: 4.9015e-04 - MAE: 0.0155 - val_loss: 4.4163e-04 - val_MAE: 0.0149

# %%
from wavy.plot import PanelFigure
from wavy.utils import reverse_pct_change
import plotly.io as pio

pio.templates.default = "plotly_white"

# %%
rev_y = reverse_pct_change(y, hist)
rev_y_pred = reverse_pct_change(y_pred, hist)
# Out:
# /Users/rodrigonader/Repos/wavy/wavy/panel.py:481: UserWarning:
#
# Sizes don't match. Using dataframe indexes and columns to update.
#
# /Users/rodrigonader/Repos/wavy/wavy/panel.py:481: UserWarning:
#
# Sizes don't match. Using dataframe indexes and columns to update.

# %%
fig = PanelFigure()
fig.add_bar(y_pred.test)
fig.add_bar(y.test)
fig.show()

# %%
x.plot_slider(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/rodrigonader/Repos/wavy/plot_tests.ipynb Cell 34' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/rodrigonader/Repos/wavy/plot_tests.ipynb#ch0000033?line=0'>1</a> x.plot_slider(10)
#
# File ~/Repos/wavy/wavy/panel.py:121, in Panel.__getattr__.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/rodrigonader/Repos/wavy/wavy/panel.py?line=119'>120</a> def wrapper(*args, **kwargs):
# --> <a href='file:///Users/rodrigonader/Repos/wavy/wavy/panel.py?line=120'>121</a>     return Panel([getattr(frame, name)(*args, **kwargs) for frame in self.frames])
#
# File ~/Repos/wavy/wavy/panel.py:121, in <listcomp>(.0)
#     <a href='file:///Users/rodrigonader/Repos/wavy/wavy/panel.py?line=119'>120</a> def wrapper(*args, **kwargs):
# --> <a href='file:///Users/rodrigonader/Repos/wavy/wavy/panel.py?line=120'>121</a>     return Panel([getattr(frame, name)(*args, **kwargs) for frame in self.frames])
#
# File ~/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5568'>5569</a>     name not in self._internal_names_set
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5569'>5570</a>     and name not in self._metadata
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5570'>5571</a>     and name not in self._accessors
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5571'>5572</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5572'>5573</a> ):
#    <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5573'>5574</a>     return self[name]
# -> <a href='file:///Users/rodrigonader/miniforge3/envs/tf/lib/python3.8/site-packages/pandas/core/generic.py?line=5574'>5575</a> return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'plot_slider'

# %%
# TODO: For how many points I got a correct direction (not value)
